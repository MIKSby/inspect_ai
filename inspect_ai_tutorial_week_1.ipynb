# %% [markdown]
# # Tutorial 1: Basics and first contact with Inspect AI
#
# Welcome to the first tutorial in our AI Safety Evaluations course.
#
# **What you'll learn:**
#
# - Connect Inspect AI to a language model (locally via Ollama, or via cloud API)
# - Run your first evaluation
# - Understand how tasks are structured: dataset → solver → scorer
# - View and analyze results with `inspect view`
# - Create single choice and multiple choice benchmarks
# - Analyzing position bias in multiple-choice tasks
#
# **By the end:** You'll have a working evaluation pipeline and understand how to build your own benchmarks.

# %% [markdown]
# ---
# ## Prerequisites: Model setup
#
# > **💡 Inspect AI only needs a model name** — the model itself can come from anywhere.
#
# **In this tutorial, we'll use Ollama and Perplexity, SambaNova as examples**, but you can substitute any provider: OpenAI, Anthropic, Google, local inference servers, or any OpenAI-compatible endpoint.
#
# **Cost note:** Cloud APIs have small free tiers and then charge per token. Local models (Ollama) are completely free. For this course, a local model is sufficient for all assignments.
#
# See [Inspect AI models docs](https://inspect.ai-safety-institute.org.uk/models.html) for the full list.

# %% [markdown]
# ---
# ## Part 1: Local environment setup (Ollama)
#
# Running evaluations locally gives you complete control and privacy.

# %% [markdown]
# ### 1.1. Installing Ollama
#
# **Before running this notebook, install Ollama:**
#
# **macOS:** `brew install ollama` or download from https://ollama.ai/download
#
# **Linux:**
# ```bash
# curl -fsSL https://ollama.ai/install.sh | sh
# ```
#
# **Windows:** download from https://ollama.ai/download
#
# After installation, start the server and download a model:
# ```bash
# ollama serve
# ollama pull llama2        # or use deepseek-r1:1.5b for a smaller option
# ```

# %% [markdown]
# ### 1.2. Check Ollama connection

# %%
import requests

def check_ollama():
    """Check Ollama connection and show installed models."""
    try:
        response = requests.get("http://localhost:11434/api/tags", timeout=5)
        if response.status_code != 200:
            print("❌ Ollama returned an error")
            return False
            
        models = response.json().get('models', [])
        total_size = sum(m['size'] for m in models)
        
        print("✅ Ollama is running!")
        print(f"\n📊 Installed models: {len(models)} ({total_size / 1e9:.1f} GB total)")
        
        for m in models:
            print(f"   - {m['name']}: {m['size'] / 1e9:.2f} GB")
        
    except requests.exceptions.ConnectionError:
        print("❌ Cannot connect to Ollama")
        print("   Start it with: ollama serve")

check_ollama()
# Out:
# ✅ Ollama is running!
#
# 📊 Installed models: 3 (8.3 GB total)
#    - qwen3.5:latest: 6.59 GB
#    - tinyllama:latest: 0.64 GB
#    - deepseek-r1:1.5b: 1.12 GB

# %% [markdown]
# ---
# ## Part 2: Basic Inspect setup

# %% [markdown]
# ### 2.1. Install Inspect AI

# %%
# !uv add inspect-ai openai ipywidgets
print("✅ Installed: inspect-ai, openai")
# Out:
# Resolved 112 packages in 9ms
# Audited 107 packages in 21ms
# ✅ Installed: inspect-ai, openai

# %% [markdown]
# ## Assignment 1: 'Hello world' in eval
#
# Let's create the simplest possible evaluation!
#
# **To do:** add one more `Sample()` to the dataset.

# %%
from inspect_ai import Task, task, eval
from inspect_ai.dataset import Sample
from inspect_ai.scorer import exact, match, model_graded_fact, choice, pattern
from inspect_ai.solver import (
    generate, system_message, chain_of_thought, 
    prompt_template, multiple_choice
)

# %%
@task
def hello_model():
    """Test your model setup with simple questions."""
    return Task(
        dataset=[
            Sample(
                input="Say 'Hello world!' and nothing else.",
                target="Hello world!"
            ),
            Sample(
                input="2+2=",
                target="4"
            ),
            Sample(
                input="What is the surname of Sheldon from The Big Bang Theory?",
                target="Cooper"
            ),
            Sample(
                input="What is the capital of France?",
                target="Paris",
            ),
        ],
        solver=[generate()],
        scorer= match(
            location="end",        # where to look for the answer: "begin", "end", "any", "exact"
            ignore_case=True,      # ignore case when comparing
            numeric=False          # treat as numeric comparison (normalizes numbers, different punctuation rules)
        )
    )

# %% [markdown]
# **Run the evaluation:**
#
# This will take a minute or two depending on your hardware.

# %%
eval(
    hello_model,
    model="ollama/tinyllama",
    limit=1  # Uncomment to test with just 1 sample
)
# Out:
# Output()
# [04/15/26 14:07:46] ERROR    Exception in callback Task.__step()                                ]8;id=10727810;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727811;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# [04/15/26 14:07:49] ERROR    Task was destroyed but it is pending!                              ]8;id=10727818;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727819;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-10'
#                              coro=<_async_in_context.<locals>.run_in_context() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/utils.py:60> wait_for=<Task pending name='Task-11'
#                              coro=<Kernel.shell_main() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/zmq/eventloop/zmqstream.py:563]>
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/yaml/constructor.py:325: RuntimeWarning:
# coroutine 'Kernel.shell_main' was never awaited
#   values = match.groupdict()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=10727826;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727827;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-11' coro=<Kernel.shell_main()
#                              running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ---
# ## Part 3: API setup (optional)
#
# If you don't have a GPU or want to test cloud models, you can use API providers.
#
# ### 3.1. Perplexity setup
#
# 1. Get an API key at https://www.perplexity.ai/settings/api
# 2. Set it in the cell below

# %%
# import os
# YOUR_API_KEY = ''
# os.environ['PERPLEXITY_API_KEY'] = YOUR_API_KEY  # Replace with your key

# %%
# eval(
#     hello_model,
#     model="perplexity/sonar",
#     # limit=1  # Uncomment to test with just 1 sample
# )

# %% [markdown]
# ## Sambanova
#
# Get API KEY https://cloud.sambanova.ai/apis here

# %%
# !pip install SambaNova

# %%
import dotenv
dotenv.load_dotenv()
import os

os.environ["OPENAI_API_KEY"] = os.environ["DEEPSEEK_API_KEY"]
os.environ["OPENAI_BASE_URL"] = "https://api.deepseek.com/v1"

# %%
eval(
    hello_model,
    model="openai/deepseek-chat",
    # limit=1  # Uncomment to test with just 1 sample
)
# Out:
# Output()
# [04/15/26 14:07:51] ERROR    Exception in callback Task.__step()                                ]8;id=10727838;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727839;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ---
# ## Part 4: Viewing results with Inspect view
#
# Every evaluation saves a log file. `inspect view` opens a web UI to explore them.
#
# ### 4.1. Launch Inspect view
#
# 1. In terminal, from the notebook's folder, run: `inspect view`
# 2. Open in browser: http://localhost:7575
#
# This will:
# 1. Show all evaluation logs in an interactive interface
# 2. Allow you to drill down into individual samples
#
# **Alternative options:**
#
# ```bash
# # View logs from a specific directory
# inspect view --log-dir ./experiment-logs
#
# # Use a different port
# inspect view --port 8080
# ```
#
# **Troubleshooting:**
#
# - If `inspect: command not found` → try `python -m inspect_ai view`
# - If the page won't load → check that you're in the correct folder (logs are saved relative to where you run evaluations)

# %%
# # Uncomment and run this cell if inspect view shows no logs

# import os
# from pathlib import Path
# 
# log_files = list(Path("./logs").glob("*.eval")) if Path("./logs").exists() else []
# 
# if not log_files:
#     print("❌ No log files found")
#     print("   Run at least one eval() in this notebook first")
#     print(f"   Current directory: {os.getcwd()}")
# else:
#     print(f"✅ Found {len(log_files)} log file(s):")
#     for f in sorted(log_files)[-5:]:  # show last 5
#         print(f"   {f.name}")

# %% [markdown]
# ### Assignment 2: Explore your logs
#
# In the Inspect view UI you can:
#
# - **See overall accuracy** for each evaluation run
# - **Click on individual samples** to see the model's response
# - **Compare runs** with different models or parameters
# - **Filter by metadata** (e.g., show only "hard" problems)
# - **Export results** for further analysis
#
# **Tip:** Keep `inspect view` running in a separate terminal while you work through this notebook. It auto-refreshes when new evaluations complete.

# %% [markdown]
# ---
# ## Part 5: Understanding benchmark structure
#
# ### 5.1. Task components overview
#
# Every Inspect `Task` consists of:
#
# ```
# Task {
#     dataset: [Sample, Sample, ...],    # data to evaluate on
#     solver: [Solver, Solver, ...],     # how to process
#     scorer: Scorer,                    # how to score
#     **parameters
# }
# ```
#
# **Component flow:**
# ```
# Dataset (Samples) → Solver(s) → Model → Scorer → Results
# ```

# %% [markdown]
# ### 5.2. Sample structure
#
# A Sample contains input/target pairs with optional metadata:

# %%
# Example of a fully-featured Sample
sample_example = Sample(
    input="Question or prompt",
    target="Expected answer",
    id="unique_id",
    choices=["Option A", "Option B", "Option C"],  # For multiple choice
    metadata={
        "category": "math",
        "difficulty": "hard"
    }
)

print("Sample components:")
print(f"  - input: {sample_example.input}")
print(f"  - target: {sample_example.target}")
print(f"  - choices: {sample_example.choices}")
print(f"  - metadata: {sample_example.metadata}")
# Out:
# Sample components:
#   - input: Question or prompt
#   - target: Expected answer
#   - choices: ['Option A', 'Option B', 'Option C']
#   - metadata: {'category': 'math', 'difficulty': 'hard'}

# %% [markdown]
# ---
# ## Part 6: Understanding solvers
#
# ### 6.1. What is a solver?
#
# A **solver** is a function that transforms a **TaskState** (the prompt + conversation history) and optionally calls the model to generate a response.
#
# **Think of solvers as middleware that:**
# 1. Modifies the prompt (prompt engineering)
# 2. Calls the model (generation)
# 3. Processes the response (extraction, critique, etc.)
#
# ### 6.2. The solver pipeline
#
# Solvers are chained together in a pipeline:
#
# ```
# Input Sample
#     ↓
# [Solver 1: system_message]
#     ↓
# [Solver 2: prompt_template]
#     ↓
# [Solver 3: chain_of_thought]
#     ↓
# [Solver 4: generate]
#     ↓
# Model Output → Scorer → Final Result
# ```
#
# Each solver receives the TaskState, modifies it, and passes it to the next solver.
#
# ### 6.3. TaskState - the core data structure
#
# Every solver operates on a **TaskState** containing:
#
# ```
# TaskState {
#     messages: list[ChatMessage],  # Conversation history
#     output: ModelOutput,          # Final model output
#     user_prompt: str,             # Current user prompt
#     input_text: str,              # Original input
#     metadata: dict,               # Sample metadata
#     choices: list[str],           # For multiple choice
#     model: ModelName,             # Current model
#     sample_id: int | str,         # Sample identifier
# }
# ```

# %% [markdown]
# ---
# ## Part 7: Built-in solvers
#
# **system_message**
# ```python
# system_message(
#     message: str        # REQUIRED - the system prompt
# )
# ```
#
# **prompt_template**
# ```python
# prompt_template(
#     template: str       # REQUIRED - use {prompt} as placeholder
# )
# ```
#
# **chain_of_thought**
# ```python
# chain_of_thought(
#     template: str = None   # optional - custom CoT prompt (default: "Let's think step by step")
# )
# ```
#
# **generate**
# ```python
# generate(
#     max_tokens: int = None,      # optional - limit response length
#     temperature: float = None,   # optional - 0.0 = deterministic, 1.0 = creative
#     top_p: float = None,         # optional - nucleus sampling
#     stop_seqs: list[str] = None  # optional - stop generation at these strings
# )
# ```
#
# **multiple_choice**
# ```python
# multiple_choice(
#     cot: bool = False,              # optional - add chain-of-thought
#     multiple_correct: bool = False, # optional - allow multiple answers
#     shuffle: bool = False           # optional - randomize choice order
# )
# ```
#
# **Typical pipeline:**
# ```
# system_message → prompt_template → chain_of_thought → generate
# ```
#
# `multiple_choice()` replaces the entire chain - it handles prompting and generation internally.
#
# **Viewing solver execution:** in `inspect view`, click any sample → messages tab shows each solver's contribution.

# %% [markdown]
# ### 7.1 system_message()
#
# **Purpose:** prepend a system role message to guide model behavior.
#
# **When to use:**
# - establish the model's role or persona
# - set global guidelines or constraints
# - define the evaluation context

# %%
@task
def example_system_message():
    """
    Demonstrates system_message() solver.
    The system prompt tells the model to be concise.
    """
    return Task(
        dataset=[
            Sample(input="What is 15 * 8?", target="120"),
            Sample(input="What is 99 + 1?", target="100"),
        ],
        solver=[
            system_message("You are a calculator. Reply with only the number, nothing else."),
            generate()
        ],
        scorer=match(numeric=True),
    )

# Run and check the Messages tab in inspect view
eval(example_system_message, model="openai/deepseek-chat")
# Out:
# [04/15/26 14:07:54] ERROR    Task was destroyed but it is pending!                              ]8;id=10727850;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727851;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-59'
#                              coro=<_async_in_context.<locals>.run_in_context() done, defined at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/utils.py:57> wait_for=<Task pending name='Task-60'
#                              coro=<Kernel.shell_main() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/zmq/eventloop/zmqstream.py:563]>
# /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/inspect.py:3226: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   for param in itertools.chain(parameters_ex, parameters):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=10727858;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727859;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-60' coro=<Kernel.shell_main()
#                              running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Output()
# [04/15/26 14:07:55] ERROR    Exception in callback Task.__step()                                ]8;id=10727866;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727867;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### 7.2 prompt_template()
#
# **Purpose:** substitute variables into a template to reformat prompts.
#
# **When to use:**
# - add specific output format requirements
# - include examples or demonstrations
# - structure prompts consistently
# - add reasoning steps or breakdowns

# %%
STEP_BY_STEP_TEMPLATE = '''
Solve this problem step by step:

Problem: {prompt}

Structure:
1. Understand the problem
2. Plan your approach
3. Solve it
4. Final answer format: ANSWER: <value>
'''.strip()

@task
def example_prompt_template():
    """
    Demonstrates prompt_template() solver.
    The template adds structure to the prompt.
    """
    return Task(
        dataset=[
            Sample(input="What is 25 * 4?", target="100"),
            Sample(input="What is 144 / 12?", target="12"),
        ],
        solver=[
            system_message("You are a math tutor."),
            prompt_template(STEP_BY_STEP_TEMPLATE),
            generate()
        ],
        scorer=match(numeric=True),
    )

# Run and see how the template structures the prompt
eval(example_prompt_template, model="openai/deepseek-chat")
# Out:
# [04/15/26 14:07:56] ERROR    Task was destroyed but it is pending!                              ]8;id=10727878;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727879;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-98'
#                              coro=<_async_in_context.<locals>.run_in_context() done, defined at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/utils.py:57> wait_for=<Task pending name='Task-99'
#                              coro=<Kernel.shell_main() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/zmq/eventloop/zmqstream.py:563]>
# /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/dataclasses.py:1564: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   for f in getattr(obj, _FIELDS).values():
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=10727886;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727887;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-99' coro=<Kernel.shell_main()
#                              running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Output()
# [04/15/26 14:07:57] ERROR    Exception in callback Task.__step()                                ]8;id=10727894;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727895;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### 7.3 chain_of_thought()
#
# **Purpose:** ask the model to "think step by step" before answering.
#
# **When to use:**
# - math and logic problems
# - multi-step reasoning tasks
# - when you want to see the model's thought process

# %%
@task
def example_chain_of_thought():
    """
    Demonstrates chain_of_thought() solver.
    Compare accuracy with and without CoT in inspect view.
    """
    return Task(
        dataset=[
            Sample(
                input="If Alice has 3 apples and Bob gives her 2 more, how many does she have?",
                target="5"
            ),
            Sample(
                input="A train travels 100 km in 2 hours. At this rate, how far in 5 hours?",
                target="250"
            ),
        ],
        solver=[
            system_message("Solve the problem. End with: ANSWER: <number>"),
            chain_of_thought(),
            generate()
        ],
        scorer=match(numeric=True),
    )

eval(example_chain_of_thought, model="openai/deepseek-chat")
# Out:
# Output()
# [04/15/26 14:08:10] ERROR    Exception in callback Task.__step()                                ]8;id=10727920;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727921;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### 7.5. multiple_choice()
#
# Special solver for A/B/C/D questions. Handles formatting and answer extraction automatically.
#
# **When to use:**
# - multiple choice questions (use instead of generate)
# - must have letter target: "A", "B", "C", etc.
#
# **Note:** When using `multiple_choice()`, use `choice()` as the scorer.

# %%
@task
def example_multiple_choice_with_cot():
    """
    Demonstrates multiple_choice(cot=True).
    Model reasons before selecting an answer.
    """
    return Task(
        dataset=[
            Sample(
                input="Light travels faster than sound. If you see lightning and hear thunder 3 seconds later, approximately how far away was the strike?",
                choices=["100 meters", "1 kilometer", "3 kilometers", "10 kilometers"],
                target="B"  # ~1 km (sound travels ~340 m/s)
            ),
        ],
        solver=multiple_choice(cot=True),
        scorer=choice(),
    )

eval(example_multiple_choice_with_cot, model="openai/deepseek-chat")
# Out:
# Output()
#                     ERROR    Exception in callback Task.__step()                                ]8;id=10727946;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727947;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### 7.6 Other solvers
#
# **self_critique()** - Have model refine its own answer
# ```python
# solver=[generate(), self_critique()]
# ```
#
# **use_tools()** - Enable tool/function calling
# ```python
# solver=[use_tools(calculator()), generate()]
# ```

# %% [markdown]
# ---
# ## Part 8: Single choice tasks
#
# Single choice tasks present the model with limited options to select from.
#
# ### 8.1. Simple yes/no classification
#
# The simplest single choice - binary classification:

# %%
@task
def yes_no_classification():
    return Task(
        dataset=[
            Sample(
                input="Is Python a programming language?",
                target="Yes"
            ),
            Sample(
                input="Is water dry?",
                target="No"
            ),
            Sample(
                input="Is the Earth round?",
                target="Yes"
            ),
        ],
        solver=[
            system_message("Answer 'Yes' or 'No'. Be concise."),
            generate()
        ],
        scorer=exact(),
    )

eval(
    yes_no_classification,
    model="openai/deepseek-chat"
)
# Out:
# Output()
# [04/15/26 14:08:25] ERROR    Exception in callback Task.__step()                                ]8;id=10727972;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727973;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### 8.2. Multi-class classification
#
# In multi-class classification, the model must choose from 3+ categories. This is common for:
# - sentiment analysis (positive / negative / neutral)
# - topic classification (sports / politics / tech / ...)
# - intent detection (question / command / statement)
#
# ---
#
# ### Task 2: Build a sentiment classifier
#
# **Your goal:** Create a sentiment classification task with at least 4 samples.
#
# **Note:**
# - `system_message` defines the classes and output format
# - `target` must exactly match one of your class labels

# %%
@task
def sentiment_classification():
    return Task(
        dataset=[
            Sample(
                input="This model answered all my questions instantly and the explanations were crystal clear. Incredible tool!",
                target="positive"
            ),
            Sample(
                input="The AI constantly misunderstands my questions and provides irrelevant answers. Very frustrating experience.",
                target="negative"
            ),
            Sample(
                input="The tool works adequately but sometimes gives overly verbose responses. It's okay.",
                target="neutral"
            ),
            Sample(
                input="Absolutely love this AI assistant! It has transformed how I work and saved me countless hours.",
                target="positive"
            ),

        ],
        solver=[
            system_message(
                "Classify the sentiment of the user's text about an AI tool.\n"
                "Reply with exactly one word -- one of: 'positive', 'negative', 'neutral'.\n"
                "Be concise."
            ),
            generate()
        ],
        scorer=exact()
    )


eval(
    sentiment_classification,
    model="openai/deepseek-chat"
)
# Out:
# [04/15/26 14:08:27] ERROR    Task was destroyed but it is pending!                              ]8;id=10727984;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727985;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-210'
#                              coro=<_async_in_context.<locals>.run_in_context() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/utils.py:60> wait_for=<Task pending name='Task-211'
#                              coro=<Kernel.shell_main() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/zmq/eventloop/zmqstream.py:563]>
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/pydantic/main.py:424: RuntimeWarning: coroutine
# 'Kernel.shell_main' was never awaited
#   copied.__pydantic_fields_set__.update(update.keys())
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=10727992;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10727993;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-211' coro=<Kernel.shell_main()
#                              running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Output()
# [04/15/26 14:08:28] ERROR    Exception in callback Task.__step()                                ]8;id=10728000;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728001;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### 8.3. Single choice with explanation
#
# Collect both choice and reasoning:

# %%
@task
def choice_with_reasoning():
    PROMPT = '''
Classify as True or False:

Statement: {prompt}

Provide:
1. REASONING: [Your explanation]
2. ANSWER: [True or False]
    '''.strip()

    return Task(
        dataset=[
            Sample(
                input="The Earth is flat.",
                target="False"
            ),
            Sample(
                input="Water boils at 100°C at sea level.",
                target="True"
            ),
        ],
        solver=[
            chain_of_thought(),
            prompt_template(PROMPT),
            generate()
        ],
        scorer=pattern(r'ANSWER:\s*(True|False)'),
    )

eval(choice_with_reasoning, model='openai/deepseek-chat')
# Out:
# [04/15/26 14:08:29] ERROR    Task was destroyed but it is pending!                              ]8;id=10728012;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728013;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-254'
#                              coro=<_async_in_context.<locals>.run_in_context() done, defined at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/utils.py:57> wait_for=<Task pending name='Task-255'
#                              coro=<Kernel.shell_main() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/zmq/eventloop/zmqstream.py:563]>
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/model/_model.py:1958:
# RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   role_usage_context_var.set({})
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=10728020;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728021;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-255' coro=<Kernel.shell_main()
#                              running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Output()
# [04/15/26 14:08:30] ERROR    Exception in callback Task.__step()                                ]8;id=10728028;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728029;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ---
# ## Part 9: Multiple choice tasks
#
# ### 9.1. Understanding multiple choice in Inspect
#
# Key rules:
# - `choices`: list of answer options (no letters — they're added automatically)
# - `target`: letter of correct answer ("A", "B", "C", or "D")
# - Use `multiple_choice()` solver + `choice()` scorer

# %% [markdown]
# ### 9.2. Multiple choice with metadata
#
# Metadata lets you filter and analyze results in `inspect view`.

# %%
@task
def mc_with_metadata():
    return Task(
        dataset=[
            Sample(
                input="Capital of Japan?",
                choices=["Seoul", "Tokyo", "Bangkok", "Beijing"],
                target="B",
                metadata={
                    "difficulty": "easy",
                    "category": "geography"
                }
            ),
            Sample(
                input="What is the Heisenberg Uncertainty Principle?",
                choices=[
                    "Cannot know both position and momentum precisely",
                    "Energy cannot be created or destroyed",
                    "All matter has wave-particle duality",
                    "Time always moves forward"
                ],
                target="A",
                metadata={
                    "difficulty": "hard",
                    "category": "physics"
                }
            ),
        ],
        solver=multiple_choice(),
        scorer=choice(),
    )

# Run and check results in inspect view - filter by metadata!
eval(mc_with_metadata, model="openai/deepseek-chat")
# Out:
# [04/15/26 14:08:34] ERROR    Task was destroyed but it is pending!                              ]8;id=10728040;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728041;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-291'
#                              coro=<_async_in_context.<locals>.run_in_context() done, defined at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/utils.py:57> wait_for=<Task pending name='Task-292'
#                              coro=<Kernel.shell_main() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/zmq/eventloop/zmqstream.py:563]>
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=10728048;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728049;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-292' coro=<Kernel.shell_main()
#                              running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Output()
# [04/15/26 14:08:35] ERROR    Exception in callback Task.__step()                                ]8;id=10728056;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728057;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### 9.6. Multiple correct Answers
#
# When multiple answers are valid:

# %%
@task
def mc_multiple_correct():
    return Task(
        dataset=[
            Sample(
                input="Which are programming languages?",
                choices=["Python", "HTML", "JavaScript", "CSS"],
                target=["A", "C"]  # Python, JavaScript
            ),
            Sample(
                input="Which continents border the Atlantic Ocean?",
                choices=["Africa", "Asia", "Europe", "South America"],
                target=["A", "C", "D"]  # Africa, Europe, South America
            ),
        ],
        solver=[
            system_message("Select ALL correct answers. You may choose multiple options."),
            multiple_choice(multiple_correct=True)
        ],
        scorer=choice(),
    )

eval(mc_multiple_correct, model="openai/deepseek-chat")
# Out:
# [04/15/26 14:08:36] ERROR    Task was destroyed but it is pending!                              ]8;id=10728068;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728069;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-318'
#                              coro=<_async_in_context.<locals>.run_in_context() done, defined at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/utils.py:57> wait_for=<Task pending name='Task-319'
#                              coro=<Kernel.shell_main() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/zmq/eventloop/zmqstream.py:563]>
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/pydantic/main.py:263: RuntimeWarning: coroutine
# 'Kernel.shell_main' was never awaited
#   validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=10728076;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728077;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-319' coro=<Kernel.shell_main()
#                              running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Output()
#                     ERROR    Exception in callback Task.__step()                                ]8;id=10728084;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728085;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ---
# ## Part 10: Composing solvers together
#
# ## Quick reference
#
# | Task type | Solvers | Scorer |
# |-----------|---------|--------|
# | Simple Q&A | `system_message() + generate()` | `match()` |
# | Reasoning | `chain_of_thought() + generate()` | `match()` |
# | Structured output | `prompt_template() + generate()` | `pattern()` |
# | Classification | `system_message() + generate()` | `exact()` |
# | Multiple choice | `multiple_choice()` | `choice()` |
# | MC + reasoning | `multiple_choice(cot=True)` | `choice()` |

# %% [markdown]
# ---
# ## Assignment 3: Analyzing position bias in multiple choice
#
# Language models can develop **position bias** - a tendency to favor certain answer positions (like more often picking "A" or "C") regardless of content.
#
# In this assignment, you will:
# 1. Generate a set of simple math questions in multiple-choice format
# 2. Create two versions of the dataset:
#    - **Biased:** correct answer is always position A
#    - **Unbiased:** correct answer position is randomized
# 3. Run evaluations on both and compare results
# 4. Analyze whether the model shows position bias
#
# ⚠️ **Note on methodology:** this is a minimal experiment to get you started. Comparing "all-A" vs "randomized" datasets is a quick sanity check, but it's not the most rigorous way to measure position bias.
#
# Feel free to extend the assignment if you want a deeper analysis!

# %%
import random
from inspect_ai import Task, task, eval
from inspect_ai.dataset import Sample
from inspect_ai.scorer import choice
from inspect_ai.solver import multiple_choice, system_message

# For reproducibility
random.seed(42)

# %% [markdown]
# ### Step 1: Generate questions
#
# First, create a helper function that generates simple questions with known correct answers.
#
# **Function spec:**
# - Input: `n` (number of problems to generate)
# - Output: list of tuples `(question_text, correct_answer)`
# - Example output: `[("What is 5 + 3?", "8"), ("What is 12 - 4?", "8"), ...]`
#
# **This is just an example.** You can implement your own generator with different content - trivia, vocabulary, geography, etc. Just make sure the model can reasonably answer them.

# %%
def generate_questions(n: int) -> list[tuple[str, int]]:
    """
    Generate n simple math problems.
    
    Args:
        n: number of problems to generate
        
    Returns:
        List of (question_text, correct_answer) tuples
    """
    problems = []
    
    for _ in range(n):
        a = random.randint(1, 20)
        b = random.randint(1, 20)
        operation = random.choice(["+", "-"])
        
        if operation == "+":
            answer = a + b
            question = f"What is {a} + {b}?"
        else:
            # Ensure non-negative result
            if a < b:
                a, b = b, a
            answer = a - b
            question = f"What is {a} - {b}?"
        
        problems.append((question, str(answer)))
    
    return problems


# ===== TESTS =====
test_questions = generate_questions(5)

assert len(test_questions) == 5, f"Expected 5 questions, got {len(test_questions)}"
assert all(isinstance(q, tuple) and len(q) == 2 for q in test_questions), "Each question must be a tuple of (question_text, answer)"
assert all(isinstance(q[0], str) and isinstance(q[1], str) for q in test_questions), "Both question and answer must be strings"
assert all(len(q[0]) > 0 and len(q[1]) > 0 for q in test_questions), "Question and answer cannot be empty"

print("\nSample output:")
for q, a in test_questions:
    print(f"  {q} → {a}")
# Out:
# [04/15/26 14:08:38] ERROR    Task was destroyed but it is pending!                              ]8;id=10728096;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728097;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-345'
#                              coro=<_async_in_context.<locals>.run_in_context() done, defined at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/utils.py:57> wait_for=<Task pending name='Task-346'
#                              coro=<Kernel.shell_main() running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/zmq/eventloop/zmqstream.py:563]>
# /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/collections/__init__.py:449: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   result = tuple_new(cls, iterable)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=10728104;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728105;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              task: <Task pending name='Task-346' coro=<Kernel.shell_main()
#                              running at
#                              /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-package
#                              s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# Sample output:
#   What is 4 - 1? → 3
#   What is 8 + 8? → 16
#   What is 4 + 18? → 22
#   What is 19 + 14? → 33
#   What is 1 + 3? → 4

# %% [markdown]
# ### Step 2: Create wrong answers (distractors)
#
# For multiple choice, we need plausible wrong answers.
#
# **Function spec:**
# - Input: `correct_answer` (int)
# - Output: list of 3 wrong answers (ints), all different from correct and from each other
#
# **Tip:** generate distractors close to the correct answer (e.g., ±1, ±2, ±10) to make them plausible.

# %%
def generate_distractors(correct: str, n: int = 3) -> list[str]:
    """
    Generate n plausible wrong answers.
    
    For numeric answers: generates nearby numbers.
    For other types: you'll need to customize this.
    
    Args:
        correct: the correct answer (string)
        n: number of distractors to generate
        
    Returns:
        List of n distinct wrong answers (strings)
    """
    distractors = set()

    offsets = [-3, -2, -1, 1, 2, 3, 5, -5, 10, -10]

    correct_int = int(correct)

    while len(distractors) < n:
        offset = random.choice(offsets)
        candidate = str(correct_int + offset)
        if candidate != correct:
            distractors.add(candidate)
        
    return list(distractors)

# ===== TESTS =====
test_distractors = generate_distractors("10", n=3)

assert len(test_distractors) == 3, f"Expected 3 distractors, got {len(test_distractors)}"
assert all(isinstance(d, str) for d in test_distractors), "All distractors must be strings"
assert "10" not in test_distractors, "Distractors must not include the correct answer"
assert len(set(test_distractors)) == 3, "All distractors must be unique"

print(f"   Distractors for '10': {test_distractors}")
# Out:
#    Distractors for '10': ['11', '20', '0']

# %% [markdown]
# ### Step 3: Create multiple choice samples
#
# Now create a function that converts questions into multiple-choice format.
#
# **Function spec:**
# - Input:
#   - `questions` - list of `(question_text, correct_answer)` tuples
#   - `correct_position` - where to place correct answer:
#     - `None` → randomize position for each question
#     - `0` → always position A
#     - `1` → always position B
#     - `2` → always position C
#     - `3` → always position D
# - Output:
#     - list of `Sample` objects
#
# ⚠️ **Note on `Sample` type:**
#
# `Sample` is an Inspect AI class. For multiple choice, you create it like this:
# ```python
# Sample(
#     input="What is 2 + 2?",           # question text
#     choices=["3", "4", "5", "6"],     # list of options: list[str]
#     target="B"                         # letter of correct answer (A/B/C/D)
# )
# ```

# %%
def create_samples(
    questions: list[tuple[str, str]], 
    correct_position: int | None = None
) -> list[Sample]:
    """
    Convert questions to multiple-choice Samples.
    """
    samples = []
    letters = ["A", "B", "C", "D"]
    
    for question, correct in questions:
        
        # 1. Generate 3 distractors
        distractors = generate_distractors(correct, n=3)
        
        # 2. Build list of all options
        options = distractors[:]  # 3 wrong answers
        
        # 3. Place correct answer at the right position
        if correct_position is None:
            # Randomize: insert correct among all 4 options
            options.append(correct)
            random.shuffle(options)
            target_index = options.index(correct)
        else:
            # Insert correct at the specified index
            options.insert(correct_position, correct)
            target_index = correct_position
        
        # 4. Determine target letter
        target = letters[target_index]
        
        # 5. Create Sample
        samples.append(Sample(
            input=question,
            choices=options,
            target=target
        ))
    
    return samples


# ===== TESTS =====
test_q = [("What is 2 + 2?", "4"), ("What is 10 - 3?", "7"), ("What is 5 + 5?", "10")]
samples_fixed = create_samples(test_q, correct_position=0)
samples_random = create_samples(test_q, correct_position=None)

assert len(samples_fixed) == len(test_q), f"Expected {len(test_q)} samples, got {len(samples_fixed)}"
assert all(hasattr(s, 'input') and hasattr(s, 'choices') and hasattr(s, 'target') for s in samples_fixed), "Each sample must have 'input', 'choices', and 'target' attributes"
assert all(len(s.choices) == 4 for s in samples_fixed), "Each sample must have exactly 4 choices"
assert all(s.target == "A" for s in samples_fixed), "With correct_position=0, all targets should be 'A'"
assert all(s.choices[0] == correct for s, (_, correct) in zip(samples_fixed, test_q)), "With correct_position=0, correct answer should be first in choices"
assert all(s.target in "ABCD" for s in samples_random), "Target must be one of A, B, C, D"

# Check that correct answer is actually at the target position
for s, (_, correct) in zip(samples_random, test_q):
    target_index = "ABCD".index(s.target)
    assert s.choices[target_index] == correct, f"Correct answer '{correct}' should be at position {s.target}, but found '{s.choices[target_index]}'"

# %% [markdown]
# ### Step 4: Create the tasks
#
# Now wrap your datasets into Inspect Tasks.
#
# **Already provided:** task structure. You just need to call your functions.

# %%
@task
def position_bias_task(
    questions: list[tuple[str, int]],
    correct_position: int | None = None
):
    """
    Multiple choice evaluation task.
    
    Args:
        questions: list of (question_text, correct_answer) tuples
        correct_position: None for random, 0-3 for fixed position
    """
    samples = create_samples(questions, correct_position=correct_position)

    return Task(
        dataset=samples,
        solver=multiple_choice(),
        scorer=choice()
    )

# %% [markdown]
# ### Step 5: Generate questions and run evaluations
#
# Generate questions once, then run two evaluations:
# 1. **Biased:** correct answer always at position A
# 2. **Unbiased:** correct answer position randomized

# %%
import random

MODEL = "openai/deepseek-chat"
N_QUESTIONS = 20

random.seed(42)
questions = generate_questions(N_QUESTIONS)

eval(
    position_bias_task, 
    model=MODEL,
    task_args={"questions": questions, "correct_position": 0}
)

eval(
    position_bias_task, 
    model=MODEL,
    task_args={"questions": questions, "correct_position": None}
)
# Out:
# Output()
# [04/15/26 14:08:40] ERROR    Exception in callback Task.__step()                                ]8;id=10728112;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=10728113;file:///home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py#1833\1833]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File
#                              "/home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gn
#                              u/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7ce8dd75f480> is already entered
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:115 in run                │
# │                                                                                                                │
# │   112 │   │   loop.set_debug(debug)                                                                            │
# │   113 │   │   task = asyncio.ensure_future(main, loop=loop)                                                    │
# │   114 │   │   try:                                                                                             │
# │ > 115 │   │   │   return loop.run_until_complete(task)                                                         │
# │   116 │   │   finally:                                                                                         │
# │   117 │   │   │   if not task.done():                                                                          │
# │   118 │   │   │   │   task.cancel()                                                                            │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:212 in run_until_complete │
# │                                                                                                                │
# │   209 │   │   │   if f is not future:                                                                          │
# │   210 │   │   │   │   f._log_destroy_pending = False                                                           │
# │   211 │   │   │   while not f.done():                                                                          │
# │ > 212 │   │   │   │   self._run_once()                                                                         │
# │   213 │   │   │   │   if self._stopping:                                                                       │
# │   214 │   │   │   │   │   break                                                                                │
# │   215 │   │   │   if not f.done():                                                                             │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:247 in _run_once          │
# │                                                                                                                │
# │   244 │   │   │   else min(max(                                                                                │
# │   245 │   │   │   │   scheduled[0]._when - self.time(), 0), 86400) if scheduled                                │
# │   246 │   │   │   else None)                                                                                   │
# │ > 247 │   │   event_list = self._selector.select(timeout)                                                      │
# │   248 │   │   self._process_events(event_list)                                                                 │
# │   249 │   │                                                                                                    │
# │   250 │   │   end_time = self.time() + self._clock_resolution                                                  │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/selectors.py:468 in select   │
# │                                                                                                                │
# │   465 │   │   │                                                                                                │
# │   466 │   │   │   ready = []                                                                                   │
# │   467 │   │   │   try:                                                                                         │
# │ > 468 │   │   │   │   fd_event_list = self._selector.poll(timeout, max_ev)                                     │
# │   469 │   │   │   except InterruptedError:                                                                     │
# │   470 │   │   │   │   return ready                                                                             │
# │   471 │   │   │   for fd, event in fd_event_list:                                                              │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_eval/task/run.py:986 in        │
# │ task_run_sample                                                                                                │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:803 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    800 │   │   │   │   │   │   "unhandled errors in a TaskGroup", self._exceptions                             │
# │    801 │   │   │   │   │   ) from None                                                                         │
# │    802 │   │   │   │   elif exc_val:                                                                           │
# │ >  803 │   │   │   │   │   raise exc_val                                                                       │
# │    804 │   │   │   except BaseException as exc:                                                                │
# │    805 │   │   │   │   if self.cancel_scope.__exit__(type(exc), exc, exc.__traceback__):                       │
# │    806 │   │   │   │   │   return True                                                                         │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:771 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    768 │   │   │   │   │   │   │   self._on_completed_fut = loop.create_future()                               │
# │    769 │   │   │   │   │   │   │                                                                               │
# │    770 │   │   │   │   │   │   │   try:                                                                        │
# │ >  771 │   │   │   │   │   │   │   │   await self._on_completed_fut                                            │
# │    772 │   │   │   │   │   │   │   except CancelledError as exc:                                               │
# │    773 │   │   │   │   │   │   │   │   # Shield the scope against further cancellation attempts                │
# │    774 │   │   │   │   │   │   │   │   # as they're not productive (#695)                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:289 in    │
# │ __await__                                                                                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/tasks.py:385 in      │
# │ __wakeup                                                                                                       │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:197 in    │
# │ result                                                                                                         │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# CancelledError: Cancelled via cancel scope 7ce8a8f1f9b0 by <Task cancelling name='Task-376'
# coro=<run_coroutine.<locals>._run_with_async_filesystem() running at
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_util/_async.py:121>>
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:115 in run                │
# │                                                                                                                │
# │   112 │   │   loop.set_debug(debug)                                                                            │
# │   113 │   │   task = asyncio.ensure_future(main, loop=loop)                                                    │
# │   114 │   │   try:                                                                                             │
# │ > 115 │   │   │   return loop.run_until_complete(task)                                                         │
# │   116 │   │   finally:                                                                                         │
# │   117 │   │   │   if not task.done():                                                                          │
# │   118 │   │   │   │   task.cancel()                                                                            │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:212 in run_until_complete │
# │                                                                                                                │
# │   209 │   │   │   if f is not future:                                                                          │
# │   210 │   │   │   │   f._log_destroy_pending = False                                                           │
# │   211 │   │   │   while not f.done():                                                                          │
# │ > 212 │   │   │   │   self._run_once()                                                                         │
# │   213 │   │   │   │   if self._stopping:                                                                       │
# │   214 │   │   │   │   │   break                                                                                │
# │   215 │   │   │   if not f.done():                                                                             │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:247 in _run_once          │
# │                                                                                                                │
# │   244 │   │   │   else min(max(                                                                                │
# │   245 │   │   │   │   scheduled[0]._when - self.time(), 0), 86400) if scheduled                                │
# │   246 │   │   │   else None)                                                                                   │
# │ > 247 │   │   event_list = self._selector.select(timeout)                                                      │
# │   248 │   │   self._process_events(event_list)                                                                 │
# │   249 │   │                                                                                                    │
# │   250 │   │   end_time = self.time() + self._clock_resolution                                                  │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/selectors.py:468 in select   │
# │                                                                                                                │
# │   465 │   │   │                                                                                                │
# │   466 │   │   │   ready = []                                                                                   │
# │   467 │   │   │   try:                                                                                         │
# │ > 468 │   │   │   │   fd_event_list = self._selector.poll(timeout, max_ev)                                     │
# │   469 │   │   │   except InterruptedError:                                                                     │
# │   470 │   │   │   │   return ready                                                                             │
# │   471 │   │   │   for fd, event in fd_event_list:                                                              │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_eval/task/run.py:986 in        │
# │ task_run_sample                                                                                                │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:803 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    800 │   │   │   │   │   │   "unhandled errors in a TaskGroup", self._exceptions                             │
# │    801 │   │   │   │   │   ) from None                                                                         │
# │    802 │   │   │   │   elif exc_val:                                                                           │
# │ >  803 │   │   │   │   │   raise exc_val                                                                       │
# │    804 │   │   │   except BaseException as exc:                                                                │
# │    805 │   │   │   │   if self.cancel_scope.__exit__(type(exc), exc, exc.__traceback__):                       │
# │    806 │   │   │   │   │   return True                                                                         │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:771 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    768 │   │   │   │   │   │   │   self._on_completed_fut = loop.create_future()                               │
# │    769 │   │   │   │   │   │   │                                                                               │
# │    770 │   │   │   │   │   │   │   try:                                                                        │
# │ >  771 │   │   │   │   │   │   │   │   await self._on_completed_fut                                            │
# │    772 │   │   │   │   │   │   │   except CancelledError as exc:                                               │
# │    773 │   │   │   │   │   │   │   │   # Shield the scope against further cancellation attempts                │
# │    774 │   │   │   │   │   │   │   │   # as they're not productive (#695)                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:289 in    │
# │ __await__                                                                                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/tasks.py:385 in      │
# │ __wakeup                                                                                                       │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:197 in    │
# │ result                                                                                                         │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# CancelledError: Cancelled via cancel scope 7ce8a8f1f9b0 by <Task cancelling name='Task-376'
# coro=<run_coroutine.<locals>._run_with_async_filesystem() running at
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_util/_async.py:121>>
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:115 in run                │
# │                                                                                                                │
# │   112 │   │   loop.set_debug(debug)                                                                            │
# │   113 │   │   task = asyncio.ensure_future(main, loop=loop)                                                    │
# │   114 │   │   try:                                                                                             │
# │ > 115 │   │   │   return loop.run_until_complete(task)                                                         │
# │   116 │   │   finally:                                                                                         │
# │   117 │   │   │   if not task.done():                                                                          │
# │   118 │   │   │   │   task.cancel()                                                                            │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:212 in run_until_complete │
# │                                                                                                                │
# │   209 │   │   │   if f is not future:                                                                          │
# │   210 │   │   │   │   f._log_destroy_pending = False                                                           │
# │   211 │   │   │   while not f.done():                                                                          │
# │ > 212 │   │   │   │   self._run_once()                                                                         │
# │   213 │   │   │   │   if self._stopping:                                                                       │
# │   214 │   │   │   │   │   break                                                                                │
# │   215 │   │   │   if not f.done():                                                                             │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:247 in _run_once          │
# │                                                                                                                │
# │   244 │   │   │   else min(max(                                                                                │
# │   245 │   │   │   │   scheduled[0]._when - self.time(), 0), 86400) if scheduled                                │
# │   246 │   │   │   else None)                                                                                   │
# │ > 247 │   │   event_list = self._selector.select(timeout)                                                      │
# │   248 │   │   self._process_events(event_list)                                                                 │
# │   249 │   │                                                                                                    │
# │   250 │   │   end_time = self.time() + self._clock_resolution                                                  │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/selectors.py:468 in select   │
# │                                                                                                                │
# │   465 │   │   │                                                                                                │
# │   466 │   │   │   ready = []                                                                                   │
# │   467 │   │   │   try:                                                                                         │
# │ > 468 │   │   │   │   fd_event_list = self._selector.poll(timeout, max_ev)                                     │
# │   469 │   │   │   except InterruptedError:                                                                     │
# │   470 │   │   │   │   return ready                                                                             │
# │   471 │   │   │   for fd, event in fd_event_list:                                                              │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_eval/task/run.py:986 in        │
# │ task_run_sample                                                                                                │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:803 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    800 │   │   │   │   │   │   "unhandled errors in a TaskGroup", self._exceptions                             │
# │    801 │   │   │   │   │   ) from None                                                                         │
# │    802 │   │   │   │   elif exc_val:                                                                           │
# │ >  803 │   │   │   │   │   raise exc_val                                                                       │
# │    804 │   │   │   except BaseException as exc:                                                                │
# │    805 │   │   │   │   if self.cancel_scope.__exit__(type(exc), exc, exc.__traceback__):                       │
# │    806 │   │   │   │   │   return True                                                                         │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:771 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    768 │   │   │   │   │   │   │   self._on_completed_fut = loop.create_future()                               │
# │    769 │   │   │   │   │   │   │                                                                               │
# │    770 │   │   │   │   │   │   │   try:                                                                        │
# │ >  771 │   │   │   │   │   │   │   │   await self._on_completed_fut                                            │
# │    772 │   │   │   │   │   │   │   except CancelledError as exc:                                               │
# │    773 │   │   │   │   │   │   │   │   # Shield the scope against further cancellation attempts                │
# │    774 │   │   │   │   │   │   │   │   # as they're not productive (#695)                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:289 in    │
# │ __await__                                                                                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/tasks.py:385 in      │
# │ __wakeup                                                                                                       │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:197 in    │
# │ result                                                                                                         │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# CancelledError: Cancelled via cancel scope 7ce8a8f1f9b0 by <Task cancelling name='Task-376'
# coro=<run_coroutine.<locals>._run_with_async_filesystem() running at
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_util/_async.py:121>>
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:115 in run                │
# │                                                                                                                │
# │   112 │   │   loop.set_debug(debug)                                                                            │
# │   113 │   │   task = asyncio.ensure_future(main, loop=loop)                                                    │
# │   114 │   │   try:                                                                                             │
# │ > 115 │   │   │   return loop.run_until_complete(task)                                                         │
# │   116 │   │   finally:                                                                                         │
# │   117 │   │   │   if not task.done():                                                                          │
# │   118 │   │   │   │   task.cancel()                                                                            │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:212 in run_until_complete │
# │                                                                                                                │
# │   209 │   │   │   if f is not future:                                                                          │
# │   210 │   │   │   │   f._log_destroy_pending = False                                                           │
# │   211 │   │   │   while not f.done():                                                                          │
# │ > 212 │   │   │   │   self._run_once()                                                                         │
# │   213 │   │   │   │   if self._stopping:                                                                       │
# │   214 │   │   │   │   │   break                                                                                │
# │   215 │   │   │   if not f.done():                                                                             │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:247 in _run_once          │
# │                                                                                                                │
# │   244 │   │   │   else min(max(                                                                                │
# │   245 │   │   │   │   scheduled[0]._when - self.time(), 0), 86400) if scheduled                                │
# │   246 │   │   │   else None)                                                                                   │
# │ > 247 │   │   event_list = self._selector.select(timeout)                                                      │
# │   248 │   │   self._process_events(event_list)                                                                 │
# │   249 │   │                                                                                                    │
# │   250 │   │   end_time = self.time() + self._clock_resolution                                                  │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/selectors.py:468 in select   │
# │                                                                                                                │
# │   465 │   │   │                                                                                                │
# │   466 │   │   │   ready = []                                                                                   │
# │   467 │   │   │   try:                                                                                         │
# │ > 468 │   │   │   │   fd_event_list = self._selector.poll(timeout, max_ev)                                     │
# │   469 │   │   │   except InterruptedError:                                                                     │
# │   470 │   │   │   │   return ready                                                                             │
# │   471 │   │   │   for fd, event in fd_event_list:                                                              │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_eval/task/run.py:986 in        │
# │ task_run_sample                                                                                                │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:803 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    800 │   │   │   │   │   │   "unhandled errors in a TaskGroup", self._exceptions                             │
# │    801 │   │   │   │   │   ) from None                                                                         │
# │    802 │   │   │   │   elif exc_val:                                                                           │
# │ >  803 │   │   │   │   │   raise exc_val                                                                       │
# │    804 │   │   │   except BaseException as exc:                                                                │
# │    805 │   │   │   │   if self.cancel_scope.__exit__(type(exc), exc, exc.__traceback__):                       │
# │    806 │   │   │   │   │   return True                                                                         │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:771 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    768 │   │   │   │   │   │   │   self._on_completed_fut = loop.create_future()                               │
# │    769 │   │   │   │   │   │   │                                                                               │
# │    770 │   │   │   │   │   │   │   try:                                                                        │
# │ >  771 │   │   │   │   │   │   │   │   await self._on_completed_fut                                            │
# │    772 │   │   │   │   │   │   │   except CancelledError as exc:                                               │
# │    773 │   │   │   │   │   │   │   │   # Shield the scope against further cancellation attempts                │
# │    774 │   │   │   │   │   │   │   │   # as they're not productive (#695)                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:289 in    │
# │ __await__                                                                                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/tasks.py:385 in      │
# │ __wakeup                                                                                                       │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:197 in    │
# │ result                                                                                                         │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# CancelledError: Cancelled via cancel scope 7ce8a8f1f9b0 by <Task cancelling name='Task-376'
# coro=<run_coroutine.<locals>._run_with_async_filesystem() running at
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_util/_async.py:121>>
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:115 in run                │
# │                                                                                                                │
# │   112 │   │   loop.set_debug(debug)                                                                            │
# │   113 │   │   task = asyncio.ensure_future(main, loop=loop)                                                    │
# │   114 │   │   try:                                                                                             │
# │ > 115 │   │   │   return loop.run_until_complete(task)                                                         │
# │   116 │   │   finally:                                                                                         │
# │   117 │   │   │   if not task.done():                                                                          │
# │   118 │   │   │   │   task.cancel()                                                                            │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:212 in run_until_complete │
# │                                                                                                                │
# │   209 │   │   │   if f is not future:                                                                          │
# │   210 │   │   │   │   f._log_destroy_pending = False                                                           │
# │   211 │   │   │   while not f.done():                                                                          │
# │ > 212 │   │   │   │   self._run_once()                                                                         │
# │   213 │   │   │   │   if self._stopping:                                                                       │
# │   214 │   │   │   │   │   break                                                                                │
# │   215 │   │   │   if not f.done():                                                                             │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:247 in _run_once          │
# │                                                                                                                │
# │   244 │   │   │   else min(max(                                                                                │
# │   245 │   │   │   │   scheduled[0]._when - self.time(), 0), 86400) if scheduled                                │
# │   246 │   │   │   else None)                                                                                   │
# │ > 247 │   │   event_list = self._selector.select(timeout)                                                      │
# │   248 │   │   self._process_events(event_list)                                                                 │
# │   249 │   │                                                                                                    │
# │   250 │   │   end_time = self.time() + self._clock_resolution                                                  │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/selectors.py:468 in select   │
# │                                                                                                                │
# │   465 │   │   │                                                                                                │
# │   466 │   │   │   ready = []                                                                                   │
# │   467 │   │   │   try:                                                                                         │
# │ > 468 │   │   │   │   fd_event_list = self._selector.poll(timeout, max_ev)                                     │
# │   469 │   │   │   except InterruptedError:                                                                     │
# │   470 │   │   │   │   return ready                                                                             │
# │   471 │   │   │   for fd, event in fd_event_list:                                                              │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_eval/task/run.py:986 in        │
# │ task_run_sample                                                                                                │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:803 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    800 │   │   │   │   │   │   "unhandled errors in a TaskGroup", self._exceptions                             │
# │    801 │   │   │   │   │   ) from None                                                                         │
# │    802 │   │   │   │   elif exc_val:                                                                           │
# │ >  803 │   │   │   │   │   raise exc_val                                                                       │
# │    804 │   │   │   except BaseException as exc:                                                                │
# │    805 │   │   │   │   if self.cancel_scope.__exit__(type(exc), exc, exc.__traceback__):                       │
# │    806 │   │   │   │   │   return True                                                                         │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:771 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    768 │   │   │   │   │   │   │   self._on_completed_fut = loop.create_future()                               │
# │    769 │   │   │   │   │   │   │                                                                               │
# │    770 │   │   │   │   │   │   │   try:                                                                        │
# │ >  771 │   │   │   │   │   │   │   │   await self._on_completed_fut                                            │
# │    772 │   │   │   │   │   │   │   except CancelledError as exc:                                               │
# │    773 │   │   │   │   │   │   │   │   # Shield the scope against further cancellation attempts                │
# │    774 │   │   │   │   │   │   │   │   # as they're not productive (#695)                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:289 in    │
# │ __await__                                                                                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/tasks.py:385 in      │
# │ __wakeup                                                                                                       │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:197 in    │
# │ result                                                                                                         │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# CancelledError: Cancelled via cancel scope 7ce8a8f1f9b0 by <Task cancelling name='Task-376'
# coro=<run_coroutine.<locals>._run_with_async_filesystem() running at
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_util/_async.py:121>>
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:115 in run                │
# │                                                                                                                │
# │   112 │   │   loop.set_debug(debug)                                                                            │
# │   113 │   │   task = asyncio.ensure_future(main, loop=loop)                                                    │
# │   114 │   │   try:                                                                                             │
# │ > 115 │   │   │   return loop.run_until_complete(task)                                                         │
# │   116 │   │   finally:                                                                                         │
# │   117 │   │   │   if not task.done():                                                                          │
# │   118 │   │   │   │   task.cancel()                                                                            │
# │                                                                                                                │
# ...
# │    801 │   │   │   │   │   ) from None                                                                         │
# │    802 │   │   │   │   elif exc_val:                                                                           │
# │ >  803 │   │   │   │   │   raise exc_val                                                                       │
# │    804 │   │   │   except BaseException as exc:                                                                │
# │    805 │   │   │   │   if self.cancel_scope.__exit__(type(exc), exc, exc.__traceback__):                       │
# │    806 │   │   │   │   │   return True                                                                         │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:771 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    768 │   │   │   │   │   │   │   self._on_completed_fut = loop.create_future()                               │
# │    769 │   │   │   │   │   │   │                                                                               │
# │    770 │   │   │   │   │   │   │   try:                                                                        │
# │ >  771 │   │   │   │   │   │   │   │   await self._on_completed_fut                                            │
# │    772 │   │   │   │   │   │   │   except CancelledError as exc:                                               │
# │    773 │   │   │   │   │   │   │   │   # Shield the scope against further cancellation attempts                │
# │    774 │   │   │   │   │   │   │   │   # as they're not productive (#695)                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:289 in    │
# │ __await__                                                                                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/tasks.py:385 in      │
# │ __wakeup                                                                                                       │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:197 in    │
# │ result                                                                                                         │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# CancelledError: Cancelled via cancel scope 7ce8a8f1f9b0 by <Task cancelling name='Task-376'
# coro=<run_coroutine.<locals>._run_with_async_filesystem() running at
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_util/_async.py:121>>
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:115 in run                │
# │                                                                                                                │
# │   112 │   │   loop.set_debug(debug)                                                                            │
# │   113 │   │   task = asyncio.ensure_future(main, loop=loop)                                                    │
# │   114 │   │   try:                                                                                             │
# │ > 115 │   │   │   return loop.run_until_complete(task)                                                         │
# │   116 │   │   finally:                                                                                         │
# │   117 │   │   │   if not task.done():                                                                          │
# │   118 │   │   │   │   task.cancel()                                                                            │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:212 in run_until_complete │
# │                                                                                                                │
# │   209 │   │   │   if f is not future:                                                                          │
# │   210 │   │   │   │   f._log_destroy_pending = False                                                           │
# │   211 │   │   │   while not f.done():                                                                          │
# │ > 212 │   │   │   │   self._run_once()                                                                         │
# │   213 │   │   │   │   if self._stopping:                                                                       │
# │   214 │   │   │   │   │   break                                                                                │
# │   215 │   │   │   if not f.done():                                                                             │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:247 in _run_once          │
# │                                                                                                                │
# │   244 │   │   │   else min(max(                                                                                │
# │   245 │   │   │   │   scheduled[0]._when - self.time(), 0), 86400) if scheduled                                │
# │   246 │   │   │   else None)                                                                                   │
# │ > 247 │   │   event_list = self._selector.select(timeout)                                                      │
# │   248 │   │   self._process_events(event_list)                                                                 │
# │   249 │   │                                                                                                    │
# │   250 │   │   end_time = self.time() + self._clock_resolution                                                  │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/selectors.py:468 in select   │
# │                                                                                                                │
# │   465 │   │   │                                                                                                │
# │   466 │   │   │   ready = []                                                                                   │
# │   467 │   │   │   try:                                                                                         │
# │ > 468 │   │   │   │   fd_event_list = self._selector.poll(timeout, max_ev)                                     │
# │   469 │   │   │   except InterruptedError:                                                                     │
# │   470 │   │   │   │   return ready                                                                             │
# │   471 │   │   │   for fd, event in fd_event_list:                                                              │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_eval/task/run.py:986 in        │
# │ task_run_sample                                                                                                │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:803 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    800 │   │   │   │   │   │   "unhandled errors in a TaskGroup", self._exceptions                             │
# │    801 │   │   │   │   │   ) from None                                                                         │
# │    802 │   │   │   │   elif exc_val:                                                                           │
# │ >  803 │   │   │   │   │   raise exc_val                                                                       │
# │    804 │   │   │   except BaseException as exc:                                                                │
# │    805 │   │   │   │   if self.cancel_scope.__exit__(type(exc), exc, exc.__traceback__):                       │
# │    806 │   │   │   │   │   return True                                                                         │
# │                                                                                                                │
# │ /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:771 in         │
# │ __aexit__                                                                                                      │
# │                                                                                                                │
# │    768 │   │   │   │   │   │   │   self._on_completed_fut = loop.create_future()                               │
# │    769 │   │   │   │   │   │   │                                                                               │
# │    770 │   │   │   │   │   │   │   try:                                                                        │
# │ >  771 │   │   │   │   │   │   │   │   await self._on_completed_fut                                            │
# │    772 │   │   │   │   │   │   │   except CancelledError as exc:                                               │
# │    773 │   │   │   │   │   │   │   │   # Shield the scope against further cancellation attempts                │
# │    774 │   │   │   │   │   │   │   │   # as they're not productive (#695)                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:289 in    │
# │ __await__                                                                                                      │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/tasks.py:385 in      │
# │ __wakeup                                                                                                       │
# │                                                                                                                │
# │ /home/miks/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/futures.py:197 in    │
# │ result                                                                                                         │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# CancelledError: Cancelled via cancel scope 7ce8a8f1f9b0 by <Task cancelling name='Task-376'
# coro=<run_coroutine.<locals>._run_with_async_filesystem() running at
# /home/miks/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_util/_async.py:121>>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 9
#       5
#       6 random.seed(42)
#       7 questions = generate_questions(N_QUESTIONS)
#       8
# ----> 9 eval(
#      10     position_bias_task,
#      11     model=MODEL,
#      12     task_args={"questions": questions, "correct_position": 0}
#
# File ~/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_eval/eval.py:302, in eval(tasks, model, model_base_url, model_args, model_roles, task_args, sandbox, sandbox_cleanup, solver, tags, metadata, trace, display, approval, log_level, log_level_transcript, log_dir, log_format, limit, sample_id, sample_shuffle, epochs, fail_on_error, continue_on_fail, retry_on_error, debug_errors, message_limit, token_limit, time_limit, working_limit, cost_limit, model_cost_config, max_samples, max_dataset_memory, max_tasks, max_subprocesses, max_sandboxes, log_samples, log_realtime, log_images, log_model_api, log_refusals, log_buffer, log_shared, log_header_only, run_samples, score, score_display, eval_set_id, **kwargs)
#     299         else:
#     300             raise
# --> 302 return task_display().run_task_app(with_async_fs(run_task_app))
#
# File ~/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_display/rich/display.py:81, in RichDisplay.run_task_app(self, main)
#      78 @override
#      79 def run_task_app(self, main: Callable[[], Coroutine[None, None, TR]]) -> TR:
#      80     if running_in_notebook():
# ---> 81         return run_coroutine(main())
#      82     else:
#      83         return anyio.run(main, backend=configured_async_backend())
#
# File ~/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/inspect_ai/_util/_async.py:125, in run_coroutine(coroutine)
#     123 if running_in_notebook():
#     124     init_nest_asyncio()
# --> 125     result = asyncio.run(_run_with_async_filesystem())
#     126     return result
#     127 else:
#
# File ~/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:115, in run(main, debug, loop_factory)
#     113 task = asyncio.ensure_future(main, loop=loop)
#     114 try:
# --> 115     return loop.run_until_complete(task)
#     116 finally:
#     117     if not task.done():
#
# File ~/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:212, in _patch_loop.<locals>.run_until_complete(self, future)
#     210     f._log_destroy_pending = False
#     211 while not f.done():
# --> 212     self._run_once()
#     213     if self._stopping:
#     214         break
#
# File ~/PycharmProjects/my_ai/.venv/lib/python3.12/site-packages/nest_asyncio2.py:247, in _patch_loop.<locals>._run_once(self)
#     240     heappop(scheduled)
#     242 timeout = (
#     243     0 if ready or self._stopping
#     244     else min(max(
#     245         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     246     else None)
# --> 247 event_list = self._selector.select(timeout)
#     248 self._process_events(event_list)
#     250 end_time = self.time() + self._clock_resolution
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ### Step 7: Analyze your results
#
# Open `inspect view` and examine both evaluation runs.
#
# 1. **Accuracy comparison:**
#    - Biased task accuracy: 100%
#    - Unbiased task accuracy: 100%
#
# 2. **Your analysis**
#     - Модель deepseek-chat показала 100% accuracy в обоих условиях (biased all-A и unbiased randomized)
#     - Position bias не обнаружен — модель выбирает ответы по содержанию, а не по позиции
#     - Единственное различие: output tokens (101 vs 125), что может указывать на слегка большую "уверенность" в biased случае

# %% [markdown]
# ### Bonus challenges (optional)
#
# If you want to explore further:
#
# 1. **Try different models** - Do all models show the same bias pattern?
#
# 2. **Add Chain-of-Thought** - Does `multiple_choice(cot=True)` reduce position bias?
#
# 3. **More positions** - What if you have 5 or 6 choices instead of 4?
#
# 4. **Statistical test** - Is the position preference statistically significant? (Chi-squared test)
#
# 5. **Content factors** - What else might affect position bias?
